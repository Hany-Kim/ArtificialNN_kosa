# %% [markdown]
# ![image.png](attachment:f59dfe62-b6a8-444e-a878-14a4ce758689.png)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Conv2D
from tensorflow.keras.layers import MaxPooling2D, concatenate

model_input = Input(shape=(28,28,3))
pre = Dense(192)(model_input)
conv1 = Conv2D(64, 1, padding='same')(pre) # 1x1 conv
conv2 = Conv2D(128, 3, padding='same')(pre) # 3x3 conv
conv3 = Conv2D(32, 5, padding='same')(pre) # 5x5 conv
pool = MaxPooling2D(pool_size=(3,3), strides=1, padding='same')(pre)
model_output = concatenate([conv1, conv2, conv3, pool])

model = Model(inputs=model_input, outputs=model_output)
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_8 (InputLayer)        [(None, 28, 28, 3)]          0         []
#
#  dense_7 (Dense)             (None, 28, 28, 192)          768       ['input_8[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 28, 28, 64)           12352     ['dense_7[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 28, 28, 128)          221312    ['dense_7[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 28, 28, 32)           153632    ['dense_7[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 28, 28, 192)          0         ['dense_7[0][0]']
#  g2D)
#
#  concatenate_4 (Concatenate  (None, 28, 28, 416)          0         ['conv2d_31[0][0]',
#  )                                                                   'conv2d_32[0][0]',
# ...

# %% [markdown]
# ![image.png](attachment:402bafd9-dbed-4888-9c23-b25c0df87e42.png)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Conv2D
from tensorflow.keras.layers import MaxPooling2D, concatenate

model_input = Input(shape=(28,28,3))
pre = Dense(192)(model_input)

conv1 = Conv2D(64, 1, padding='same')(pre) # 1x1 conv

conv2_1 = Conv2D(96, 1 , padding='same')(pre)
conv2 = Conv2D(128, 3, padding='same')(conv2_1) # 3x3 conv

conv3_1 = Conv2D(16, 1 , padding='same')(pre)
conv3 = Conv2D(32, 5, padding='same')(conv3_1) # 5x5 conv

pool = MaxPooling2D(pool_size=(3,3), strides=1, padding='same')(pre)
conv4_1 = Conv2D(32, 1, padding='same')(pool)
model_output = concatenate([conv1, conv2, conv3, conv4_1])

model = Model(inputs=model_input, outputs=model_output)
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_9 (InputLayer)        [(None, 28, 28, 3)]          0         []
#
#  dense_8 (Dense)             (None, 28, 28, 192)          768       ['input_9[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 28, 28, 96)           18528     ['dense_8[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 28, 28, 16)           3088      ['dense_8[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 28, 28, 192)          0         ['dense_8[0][0]']
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 28, 28, 64)           12352     ['dense_8[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 28, 28, 128)          110720    ['conv2d_35[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 28, 28, 32)           12832     ['conv2d_37[0][0]']
#
# ...

# %% [markdown]
# ![image.png](attachment:01cd7a0e-3696-4aae-8029-8818ba90b22c.png)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Activation, add

input = Input(shape=(28,28,3))

x = Conv2D(128, 3, padding='same', activation='relu')(input)
conv = Conv2D(64, 3, padding='same',activation='relu')(x)
conv = Conv2D(128, 3, padding='same')(conv)

y = add([conv, x])
y = Activation('relu')(y)

model = Model(inputs=input, outputs=y)
model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_10 (InputLayer)       [(None, 28, 28, 3)]          0         []
#
#  conv2d_40 (Conv2D)          (None, 28, 28, 128)          3584      ['input_10[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 28, 28, 64)           73792     ['conv2d_40[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 28, 28, 128)          73856     ['conv2d_41[0][0]']
#
#  add_3 (Add)                 (None, 28, 28, 128)          0         ['conv2d_42[0][0]',
#                                                                      'conv2d_40[0][0]']
#
#  activation_3 (Activation)   (None, 28, 28, 128)          0         ['add_3[0][0]']
#
# ...
# Total params: 151232 (590.75 KB)
# Trainable params: 151232 (590.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# ...
