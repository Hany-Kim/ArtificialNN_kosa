# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2

# %%
class BatchNormalization(layers.BatchNormalization):
    def call(self, x, training=False):
        if not training:
            training = tf.constant(False)
        training = tf.logical_and(training, self.trainable)
        return super().call(x, training)

# %%
def convolutional(input_layer, filters, kernel_size,
                  downsample=False, activate=True, bn=True):
    if downsample:
        input_layer = layers.ZeroPadding2D(((1,0), (1,0)))(input_layer)
        padding = "valid"
        strides = 2
    else:
        strides = 1
        padding = "same"

    kernel_init = tf.random_normal_initializer(stddev=0.01)
    conv = layers.Conv2D(filters=filters,
                        kernel_size=kernel_size,
                        strides=strides, padding=padding,
                        use_bias=not bn,
                        kernel_initializer=kernel_init,
                        kernel_regularizer=l2(0.0005)
                        )(input_layer)
    if bn:
        conv = BatchNormalization()(conv)
    if activate:
        conv = layers.LeakyReLU(alpha=0.1)(conv)

    return conv

# %%
def residual_block(input_layer, filter_num1, filter_num2):
    short_cut = input_layer
    conv = convolutional(input_layer, filters=filter_num1,
                        kernel_size=(1,1))
    conv = convolutional(conv, filters=filter_num2,
                        kernel_size=(3,3))
    residual_output = short_cut + conv
    return residual_output

# %%
def darknet53(input_data):
    input_data = convolutional(input_data, 32, (3,3))
    input_data = convolutional(input_data, 64, (3,3),
                                downsample=True)

    for i in range(1):
        input_data = residual_block(input_data, 32, 64)

    input_data = convolutional(input_data, 128, (3, 3),
                                downsample=True)

    for i in range(2):
        input_data = residual_block(input_data, 64, 128)

    input_data = convolutional(input_data, 256, (3, 3),
                                downsample=True)

    for i in range(8):
        input_data = residual_block(input_data, 128, 256)

    route_1 = input_data
    input_data = convolutional(input_data, 512, (3, 3),
                                downsample=True)

    for i in range(8):
        input_data = residual_block(input_data, 256, 512)

    route_2 = input_data
    input_data = convolutional(input_data, 1024, (3, 3),
                                downsample=True)

    for i in range(4):
        input_data = residual_block(input_data, 512, 1024)

    return route_1, route_2, input_data

# %%
def upsample(input_layer):
    width, height = input_layer.shape[1], input_layer.shape[2]
    output_layer = tf.image.resize(input_layer,
                                    (width*2, height*2),
                                    method="nearest")
    return output_layer

# %%
def YOLOv3(input_layer, num_class):
    # Darknet-53을 실행하고 그 결과를 받음
    route_1, route_2, conv = darknet53(input_layer)

    conv = convolutional(conv, 512, (1, 1))
    conv = convolutional(conv, 1024, (3, 3))
    conv = convolutional(conv, 512, (1, 1))
    conv = convolutional(conv, 1024, (3, 3))
    conv = convolutional(conv, 512, (1, 1))
    conv_lobj_branch = convolutional(conv, 1024, (3, 3))

    # conv_lbbox는 큰 객체를 예측하기 위해 사용
    # Shape = [None, 13, 13, 255]
    conv_lbbox = convolutional(conv_lobj_branch,
                                3 * (num_class + 5), (1, 1),
                                activate=False, bn=False)

    conv = convolutional(conv, 256, (1, 1))

    # 최근방법(nearest)을 이용하여 업샘플링 함
    # 이렇게 하면 업샘플링시 학습이 필요 없으므로
    # 인공신경망 파라미터를 줄임
    conv = upsample(conv)

    conv = tf.concat([conv, route_2], axis=-1)
    conv = convolutional(conv, 256, (1, 1))
    conv = convolutional(conv, 512, (3, 3))
    conv = convolutional(conv, 256, (1, 1))
    conv = convolutional(conv, 512, (3, 3))
    conv = convolutional(conv, 256, (1, 1))
    conv_mobj_branch = convolutional(conv, 512, (3, 3))

    # conv_mbbox는 중간 크기 객체를 예측하기 위해 사용
    # shape = [None, 26, 26, 255]
    conv_mbbox = convolutional(conv_mobj_branch,
                                3 * (num_class + 5), (1, 1),
                                activate=False, bn=False)

    conv = convolutional(conv, 128, (1, 1))
    conv = upsample(conv)

    conv = tf.concat([conv, route_1], axis=-1)
    conv = convolutional(conv, 128, (1, 1))
    conv = convolutional(conv, 256, (3, 3))
    conv = convolutional(conv, 128, (1, 1))
    conv = convolutional(conv, 256, (3, 3))
    conv = convolutional(conv, 128, (1, 1))
    conv_sobj_branch = convolutional(conv, 256, (3, 3))

    # conv_sbbox는 작은 객체를 예측하기 위해 사용
    # shape = [None, 52, 52, 255]
    conv_sbbox = convolutional(conv_sobj_branch,
                                3 * (num_class + 5), (1, 1),
                                activate=False, bn=False)

    return [conv_sbbox, conv_mbbox, conv_lbbox]

# %%
import numpy as np

YOLO_STRIDES = [8, 16, 32]
YOLO_ANCHORS = [[[10, 13], [16, 30], [33, 23]],
                [[30, 61], [62, 45], [59, 119]],
                [[116, 90], [156, 198], [373, 326]]]

STRIDES = np.array(YOLO_STRIDES)
ANCHORS = (np.array(YOLO_ANCHORS).T/STRIDES).T

# %%
def decode(conv_output, num_class, i=0):
    conv_shape = tf.shape(conv_output)
    batch_size = conv_shape[0]
    output_size = conv_shape[1]

    conv_output = tf.reshape(conv_output,
                            (batch_size, output_size,
                            output_size, 3, num_class+5))

    # 상자의 x, y 위치
    conv_raw_dxdy = conv_output[:, :, :, :, 0:2]
    # 상자의 가로, 세로 크기
    conv_raw_dwdh = conv_output[:, :, :, :, 2:4]
    # 상자의 신뢰도 (confidence)
    conv_raw_conf = conv_output[:, :, :, :, 4:5]
    # 클래스별 확률
    conv_raw_prob = conv_output[:, :, :, :, 5:]

    # 그리드 출력의 크기는 13, 26, 52
    y = tf.range(output_size, dtype=tf.int32)
    y = tf.expand_dims(y, -1)
    y = tf.tile(y, [1, output_size])
    x = tf.range(output_size, dtype=tf.int32)
    x = tf.expand_dims(x, 0)
    x = tf.tile(x, [output_size, 1])

    xy_grid = tf.concat([x[:, :, tf.newaxis],
                        y[:, :, tf.newaxis]], axis=-1)
    xy_grid = tf.tile(xy_grid[tf.newaxis, :, :, tf.newaxis, :],
                        [batch_size, 1, 1, 3, 1])
    xy_grid = tf.cast(xy_grid, tf.float32)

    # 상자의 중심점을 계산
    pred_xy = (tf.sigmoid(conv_raw_dxdy) + xy_grid) * STRIDES[i]
    # 상자의 너비와 높이를 계산
    pred_wh = (tf.exp(conv_raw_dwdh) * ANCHORS[i]) * STRIDES[i]

    pred_xywh = tf.concat([pred_xy, pred_wh], axis=-1)
    pred_conf = tf.sigmoid(conv_raw_conf) # 상자의 신뢰도
    pred_prob = tf.sigmoid(conv_raw_prob) # 클래스별 확률

    return tf.concat([pred_xywh, pred_conf, pred_prob], axis=-1)

# %%
def Create_YOLOv3(num_class, input_shape=(416, 416, 3),
                  train_mode=False):
    input_layer = layers.Input(input_shape)
    conv_tensors = YOLOv3(input_layer, num_class)
    output_tensors = []
    for i, conv_tensor in enumerate(conv_tensors):
        pred_tensor = decode(conv_tensor, num_class, i)

        if train_mode: output_tensors.append(conv_tensor)
        output_tensors.append(pred_tensor)

    model = tf.keras.Model(input_layer, output_tensors)

    return model

# %%
NUM_CLASS = 10

yolo = Create_YOLOv3(num_class=NUM_CLASS, train_mode=True)

# %%
yolo.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 416, 416, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 416, 416, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 416, 416, 32)         128       ['conv2d[0][0]']
#  Normalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 416, 416, 32)         0         ['batch_normalization[0][0]']
#
#  zero_padding2d (ZeroPaddin  (None, 417, 417, 32)         0         ['leaky_re_lu[0][0]']
#  g2D)
#
#  conv2d_1 (Conv2D)           (None, 208, 208, 64)         18432     ['zero_padding2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 208, 208, 64)         256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 208, 208, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 208, 208, 32)         2048      ['leaky_re_lu_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 208, 208, 32)         128       ['conv2d_2[0][0]']
#  chNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 208, 208, 32)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 208, 208, 64)         18432     ['leaky_re_lu_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 208, 208, 64)         256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 208, 208, 64)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  tf.__operators__.add (TFOp  (None, 208, 208, 64)         0         ['leaky_re_lu_1[0][0]',
#  Lambda)                                                             'leaky_re_lu_3[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 209, 209, 64)         0         ['tf.__operators__.add[0][0]']
#  ing2D)
#
#  conv2d_4 (Conv2D)           (None, 104, 104, 128)        73728     ['zero_padding2d_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 104, 104, 128)        512       ['conv2d_4[0][0]']
#  chNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 104, 104, 128)        0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 104, 104, 64)         8192      ['leaky_re_lu_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 104, 104, 64)         256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 104, 104, 64)         0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 104, 104, 128)        73728     ['leaky_re_lu_5[0][0]']
#
#  batch_normalization_6 (Bat  (None, 104, 104, 128)        512       ['conv2d_6[0][0]']
#  chNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 104, 104, 128)        0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  tf.__operators__.add_1 (TF  (None, 104, 104, 128)        0         ['leaky_re_lu_4[0][0]',
#  OpLambda)                                                           'leaky_re_lu_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 104, 104, 64)         8192      ['tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  batch_normalization_7 (Bat  (None, 104, 104, 64)         256       ['conv2d_7[0][0]']
#  chNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 104, 104, 64)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 104, 104, 128)        73728     ['leaky_re_lu_7[0][0]']
#
#  batch_normalization_8 (Bat  (None, 104, 104, 128)        512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 104, 104, 128)        0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  tf.__operators__.add_2 (TF  (None, 104, 104, 128)        0         ['tf.__operators__.add_1[0][0]
#  OpLambda)                                                          ',
#                                                                      'leaky_re_lu_8[0][0]']
#
#  zero_padding2d_2 (ZeroPadd  (None, 105, 105, 128)        0         ['tf.__operators__.add_2[0][0]
#  ing2D)                                                             ']
#
#  conv2d_9 (Conv2D)           (None, 52, 52, 256)          294912    ['zero_padding2d_2[0][0]']
#
#  batch_normalization_9 (Bat  (None, 52, 52, 256)          1024      ['conv2d_9[0][0]']
#  chNormalization)
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 52, 52, 256)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 52, 52, 128)          32768     ['leaky_re_lu_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 52, 52, 128)          512       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 52, 52, 256)          1024      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  tf.__operators__.add_3 (TF  (None, 52, 52, 256)          0         ['leaky_re_lu_9[0][0]',
#  OpLambda)                                                           'leaky_re_lu_11[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  batch_normalization_12 (Ba  (None, 52, 52, 128)          512       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 52, 52, 256)          1024      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  tf.__operators__.add_4 (TF  (None, 52, 52, 256)          0         ['tf.__operators__.add_3[0][0]
#  OpLambda)                                                          ',
#                                                                      'leaky_re_lu_13[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  batch_normalization_14 (Ba  (None, 52, 52, 128)          512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 52, 52, 256)          1024      ['conv2d_15[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  tf.__operators__.add_5 (TF  (None, 52, 52, 256)          0         ['tf.__operators__.add_4[0][0]
#  OpLambda)                                                          ',
#                                                                      'leaky_re_lu_15[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  batch_normalization_16 (Ba  (None, 52, 52, 128)          512       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 52, 52, 256)          1024      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  tf.__operators__.add_6 (TF  (None, 52, 52, 256)          0         ['tf.__operators__.add_5[0][0]
#  OpLambda)                                                          ',
#                                                                      'leaky_re_lu_17[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  batch_normalization_18 (Ba  (None, 52, 52, 128)          512       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 52, 52, 256)          1024      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  tf.__operators__.add_7 (TF  (None, 52, 52, 256)          0         ['tf.__operators__.add_6[0][0]
#  OpLambda)                                                          ',
#                                                                      'leaky_re_lu_19[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  batch_normalization_20 (Ba  (None, 52, 52, 128)          512       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 52, 52, 256)          1024      ['conv2d_21[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  tf.__operators__.add_8 (TF  (None, 52, 52, 256)          0         ['tf.__operators__.add_7[0][0]
#  OpLambda)                                                          ',
#                                                                      'leaky_re_lu_21[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.__operators__.add_8[0][0]
#                                                                     ']
#
#  batch_normalization_22 (Ba  (None, 52, 52, 128)          512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 52, 52, 256)          1024      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  tf.__operators__.add_9 (TF  (None, 52, 52, 256)          0         ['tf.__operators__.add_8[0][0]
#  OpLambda)                                                          ',
#                                                                      'leaky_re_lu_23[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  batch_normalization_24 (Ba  (None, 52, 52, 128)          512       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_24 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 52, 52, 256)          1024      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_25 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  tf.__operators__.add_10 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_9[0][0]
#  FOpLambda)                                                         ',
#                                                                      'leaky_re_lu_25[0][0]']
#
#  zero_padding2d_3 (ZeroPadd  (None, 53, 53, 256)          0         ['tf.__operators__.add_10[0][0
#  ing2D)                                                             ]']
#
#  conv2d_26 (Conv2D)          (None, 26, 26, 512)          1179648   ['zero_padding2d_3[0][0]']
#
#  batch_normalization_26 (Ba  (None, 26, 26, 512)          2048      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_26 (LeakyReLU)  (None, 26, 26, 512)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 26, 26, 256)          131072    ['leaky_re_lu_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 26, 26, 256)          1024      ['conv2d_27[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_27 (LeakyReLU)  (None, 26, 26, 256)          0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 26, 26, 512)          1179648   ['leaky_re_lu_27[0][0]']
#
#  batch_normalization_28 (Ba  (None, 26, 26, 512)          2048      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 26, 26, 512)          0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  tf.__operators__.add_11 (T  (None, 26, 26, 512)          0         ['leaky_re_lu_26[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_28[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 26, 26, 256)          131072    ['tf.__operators__.add_11[0][0
#                                                                     ]']
#
#  batch_normalization_29 (Ba  (None, 26, 26, 256)          1024      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 26, 26, 256)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 26, 26, 512)          1179648   ['leaky_re_lu_29[0][0]']
#
#  batch_normalization_30 (Ba  (None, 26, 26, 512)          2048      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 26, 26, 512)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  tf.__operators__.add_12 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_11[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_30[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 26, 26, 256)          131072    ['tf.__operators__.add_12[0][0
#                                                                     ]']
#
#  batch_normalization_31 (Ba  (None, 26, 26, 256)          1024      ['conv2d_31[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 26, 26, 256)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 26, 26, 512)          1179648   ['leaky_re_lu_31[0][0]']
#
#  batch_normalization_32 (Ba  (None, 26, 26, 512)          2048      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 26, 26, 512)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  tf.__operators__.add_13 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_12[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_32[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 26, 26, 256)          131072    ['tf.__operators__.add_13[0][0
#                                                                     ]']
#
#  batch_normalization_33 (Ba  (None, 26, 26, 256)          1024      ['conv2d_33[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 26, 26, 256)          0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 26, 26, 512)          1179648   ['leaky_re_lu_33[0][0]']
#
#  batch_normalization_34 (Ba  (None, 26, 26, 512)          2048      ['conv2d_34[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_34 (LeakyReLU)  (None, 26, 26, 512)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  tf.__operators__.add_14 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_13[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_34[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 26, 26, 256)          131072    ['tf.__operators__.add_14[0][0
#                                                                     ]']
#
#  batch_normalization_35 (Ba  (None, 26, 26, 256)          1024      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_35 (LeakyReLU)  (None, 26, 26, 256)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 26, 26, 512)          1179648   ['leaky_re_lu_35[0][0]']
#
#  batch_normalization_36 (Ba  (None, 26, 26, 512)          2048      ['conv2d_36[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_36 (LeakyReLU)  (None, 26, 26, 512)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  tf.__operators__.add_15 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_14[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_36[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 26, 26, 256)          131072    ['tf.__operators__.add_15[0][0
#                                                                     ]']
#
#  batch_normalization_37 (Ba  (None, 26, 26, 256)          1024      ['conv2d_37[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_37 (LeakyReLU)  (None, 26, 26, 256)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 26, 26, 512)          1179648   ['leaky_re_lu_37[0][0]']
#
#  batch_normalization_38 (Ba  (None, 26, 26, 512)          2048      ['conv2d_38[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_38 (LeakyReLU)  (None, 26, 26, 512)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  tf.__operators__.add_16 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_15[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_38[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 26, 26, 256)          131072    ['tf.__operators__.add_16[0][0
#                                                                     ]']
#
#  batch_normalization_39 (Ba  (None, 26, 26, 256)          1024      ['conv2d_39[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_39 (LeakyReLU)  (None, 26, 26, 256)          0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 26, 26, 512)          1179648   ['leaky_re_lu_39[0][0]']
#
#  batch_normalization_40 (Ba  (None, 26, 26, 512)          2048      ['conv2d_40[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_40 (LeakyReLU)  (None, 26, 26, 512)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  tf.__operators__.add_17 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_16[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_40[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 26, 26, 256)          131072    ['tf.__operators__.add_17[0][0
#                                                                     ]']
#
#  batch_normalization_41 (Ba  (None, 26, 26, 256)          1024      ['conv2d_41[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_41 (LeakyReLU)  (None, 26, 26, 256)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 26, 26, 512)          1179648   ['leaky_re_lu_41[0][0]']
#
#  batch_normalization_42 (Ba  (None, 26, 26, 512)          2048      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_42 (LeakyReLU)  (None, 26, 26, 512)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  tf.__operators__.add_18 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_17[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_42[0][0]']
#
#  zero_padding2d_4 (ZeroPadd  (None, 27, 27, 512)          0         ['tf.__operators__.add_18[0][0
#  ing2D)                                                             ]']
#
#  conv2d_43 (Conv2D)          (None, 13, 13, 1024)         4718592   ['zero_padding2d_4[0][0]']
#
#  batch_normalization_43 (Ba  (None, 13, 13, 1024)         4096      ['conv2d_43[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_43 (LeakyReLU)  (None, 13, 13, 1024)         0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 13, 13, 512)          524288    ['leaky_re_lu_43[0][0]']
#
#  batch_normalization_44 (Ba  (None, 13, 13, 512)          2048      ['conv2d_44[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_44 (LeakyReLU)  (None, 13, 13, 512)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 13, 13, 1024)         4718592   ['leaky_re_lu_44[0][0]']
#
#  batch_normalization_45 (Ba  (None, 13, 13, 1024)         4096      ['conv2d_45[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_45 (LeakyReLU)  (None, 13, 13, 1024)         0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  tf.__operators__.add_19 (T  (None, 13, 13, 1024)         0         ['leaky_re_lu_43[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_45[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 13, 13, 512)          524288    ['tf.__operators__.add_19[0][0
#                                                                     ]']
#
#  batch_normalization_46 (Ba  (None, 13, 13, 512)          2048      ['conv2d_46[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_46 (LeakyReLU)  (None, 13, 13, 512)          0         ['batch_normalization_46[0][0]
# ...
#                                                                      'tf.__operators__.getitem_19[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_19[
#                                                                     0][0]']
#
#  tf.__operators__.getitem_2  (1, 13, 13, 1, 2)            0         ['tf.concat_8[0][0]']
#  6 (SlicingOpLambda)
#
#  tf.__operators__.getitem_2  (None, 52, 52, 3, 2)         0         ['tf.reshape[0][0]']
#   (SlicingOpLambda)
#
#  tf.tile_2 (TFOpLambda)      (None, 52, 52, 3, 2)         0         ['tf.__operators__.getitem_8[0
#                                                                     ][0]',
#                                                                      'tf.__operators__.getitem[0][
#                                                                     0]']
#
#  tf.__operators__.getitem_3  (None, 52, 52, 3, 2)         0         ['tf.reshape[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem_1  (None, 26, 26, 3, 2)         0         ['tf.reshape_1[0][0]']
#  1 (SlicingOpLambda)
#
#  tf.tile_5 (TFOpLambda)      (None, 26, 26, 3, 2)         0         ['tf.__operators__.getitem_17[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_9[0
#                                                                     ][0]']
#
#  tf.__operators__.getitem_1  (None, 26, 26, 3, 2)         0         ['tf.reshape_1[0][0]']
#  2 (SlicingOpLambda)
#
#  tf.__operators__.getitem_2  (None, 13, 13, 3, 2)         0         ['tf.reshape_2[0][0]']
#  0 (SlicingOpLambda)
#
#  tf.tile_8 (TFOpLambda)      (None, 13, 13, 3, 2)         0         ['tf.__operators__.getitem_26[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_18[
#                                                                     0][0]']
#
#  tf.__operators__.getitem_2  (None, 13, 13, 3, 2)         0         ['tf.reshape_2[0][0]']
#  1 (SlicingOpLambda)
#
#  tf.math.sigmoid (TFOpLambd  (None, 52, 52, 3, 2)         0         ['tf.__operators__.getitem_2[0
#  a)                                                                 ][0]']
#
#  tf.cast (TFOpLambda)        (None, 52, 52, 3, 2)         0         ['tf.tile_2[0][0]']
#
#  tf.math.exp (TFOpLambda)    (None, 52, 52, 3, 2)         0         ['tf.__operators__.getitem_3[0
#                                                                     ][0]']
#
#  tf.math.sigmoid_3 (TFOpLam  (None, 26, 26, 3, 2)         0         ['tf.__operators__.getitem_11[
#  bda)                                                               0][0]']
#
#  tf.cast_1 (TFOpLambda)      (None, 26, 26, 3, 2)         0         ['tf.tile_5[0][0]']
#
#  tf.math.exp_1 (TFOpLambda)  (None, 26, 26, 3, 2)         0         ['tf.__operators__.getitem_12[
#                                                                     0][0]']
#
#  tf.math.sigmoid_6 (TFOpLam  (None, 13, 13, 3, 2)         0         ['tf.__operators__.getitem_20[
#  bda)                                                               0][0]']
#
#  tf.cast_2 (TFOpLambda)      (None, 13, 13, 3, 2)         0         ['tf.tile_8[0][0]']
#
#  tf.math.exp_2 (TFOpLambda)  (None, 13, 13, 3, 2)         0         ['tf.__operators__.getitem_21[
#                                                                     0][0]']
#
#  tf.__operators__.add_23 (T  (None, 52, 52, 3, 2)         0         ['tf.math.sigmoid[0][0]',
#  FOpLambda)                                                          'tf.cast[0][0]']
#
#  tf.math.multiply_1 (TFOpLa  (None, 52, 52, 3, 2)         0         ['tf.math.exp[0][0]']
#  mbda)
#
#  tf.__operators__.add_24 (T  (None, 26, 26, 3, 2)         0         ['tf.math.sigmoid_3[0][0]',
#  FOpLambda)                                                          'tf.cast_1[0][0]']
#
#  tf.math.multiply_4 (TFOpLa  (None, 26, 26, 3, 2)         0         ['tf.math.exp_1[0][0]']
#  mbda)
#
#  tf.__operators__.add_25 (T  (None, 13, 13, 3, 2)         0         ['tf.math.sigmoid_6[0][0]',
#  FOpLambda)                                                          'tf.cast_2[0][0]']
#
#  tf.math.multiply_7 (TFOpLa  (None, 13, 13, 3, 2)         0         ['tf.math.exp_2[0][0]']
#  mbda)
#
#  tf.math.multiply (TFOpLamb  (None, 52, 52, 3, 2)         0         ['tf.__operators__.add_23[0][0
#  da)                                                                ]']
#
#  tf.math.multiply_2 (TFOpLa  (None, 52, 52, 3, 2)         0         ['tf.math.multiply_1[0][0]']
#  mbda)
#
#  tf.__operators__.getitem_4  (None, 52, 52, 3, 1)         0         ['tf.reshape[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem_5  (None, 52, 52, 3, 10)        0         ['tf.reshape[0][0]']
#   (SlicingOpLambda)
#
#  tf.math.multiply_3 (TFOpLa  (None, 26, 26, 3, 2)         0         ['tf.__operators__.add_24[0][0
#  mbda)                                                              ]']
#
#  tf.math.multiply_5 (TFOpLa  (None, 26, 26, 3, 2)         0         ['tf.math.multiply_4[0][0]']
#  mbda)
#
#  tf.__operators__.getitem_1  (None, 26, 26, 3, 1)         0         ['tf.reshape_1[0][0]']
#  3 (SlicingOpLambda)
#
#  tf.__operators__.getitem_1  (None, 26, 26, 3, 10)        0         ['tf.reshape_1[0][0]']
#  4 (SlicingOpLambda)
#
#  tf.math.multiply_6 (TFOpLa  (None, 13, 13, 3, 2)         0         ['tf.__operators__.add_25[0][0
#  mbda)                                                              ]']
#
#  tf.math.multiply_8 (TFOpLa  (None, 13, 13, 3, 2)         0         ['tf.math.multiply_7[0][0]']
#  mbda)
#
#  tf.__operators__.getitem_2  (None, 13, 13, 3, 1)         0         ['tf.reshape_2[0][0]']
#  2 (SlicingOpLambda)
#
#  tf.__operators__.getitem_2  (None, 13, 13, 3, 10)        0         ['tf.reshape_2[0][0]']
#  3 (SlicingOpLambda)
#
#  tf.concat_3 (TFOpLambda)    (None, 52, 52, 3, 4)         0         ['tf.math.multiply[0][0]',
#                                                                      'tf.math.multiply_2[0][0]']
#
#  tf.math.sigmoid_1 (TFOpLam  (None, 52, 52, 3, 1)         0         ['tf.__operators__.getitem_4[0
#  bda)                                                               ][0]']
#
#  tf.math.sigmoid_2 (TFOpLam  (None, 52, 52, 3, 10)        0         ['tf.__operators__.getitem_5[0
#  bda)                                                               ][0]']
#
#  tf.concat_6 (TFOpLambda)    (None, 26, 26, 3, 4)         0         ['tf.math.multiply_3[0][0]',
#                                                                      'tf.math.multiply_5[0][0]']
#
#  tf.math.sigmoid_4 (TFOpLam  (None, 26, 26, 3, 1)         0         ['tf.__operators__.getitem_13[
#  bda)                                                               0][0]']
#
#  tf.math.sigmoid_5 (TFOpLam  (None, 26, 26, 3, 10)        0         ['tf.__operators__.getitem_14[
#  bda)                                                               0][0]']
#
#  tf.concat_9 (TFOpLambda)    (None, 13, 13, 3, 4)         0         ['tf.math.multiply_6[0][0]',
#                                                                      'tf.math.multiply_8[0][0]']
#
#  tf.math.sigmoid_7 (TFOpLam  (None, 13, 13, 3, 1)         0         ['tf.__operators__.getitem_22[
#  bda)                                                               0][0]']
#
#  tf.math.sigmoid_8 (TFOpLam  (None, 13, 13, 3, 10)        0         ['tf.__operators__.getitem_23[
#  bda)                                                               0][0]']
#
#  tf.concat_4 (TFOpLambda)    (None, 52, 52, 3, 15)        0         ['tf.concat_3[0][0]',
#                                                                      'tf.math.sigmoid_1[0][0]',
#                                                                      'tf.math.sigmoid_2[0][0]']
#
#  tf.concat_7 (TFOpLambda)    (None, 26, 26, 3, 15)        0         ['tf.concat_6[0][0]',
#                                                                      'tf.math.sigmoid_4[0][0]',
#                                                                      'tf.math.sigmoid_5[0][0]']
#
#  tf.concat_10 (TFOpLambda)   (None, 13, 13, 3, 15)        0         ['tf.concat_9[0][0]',
#                                                                      'tf.math.sigmoid_7[0][0]',
#                                                                      'tf.math.sigmoid_8[0][0]']
#
# ==================================================================================================
# Total params: 61624807 (235.08 MB)
# Trainable params: 61572199 (234.88 MB)
# Non-trainable params: 52608 (205.50 KB)
# __________________________________________________________________________________________________

# %%
NUM_CLASS = 10

#from yolov3 import *

yolo = Create_YOLOv3(num_class=NUM_CLASS, train_mode=True)
yolo.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 416, 416, 3)]        0         []
#
#  conv2d_75 (Conv2D)          (None, 416, 416, 32)         864       ['input_2[0][0]']
#
#  batch_normalization_72 (Ba  (None, 416, 416, 32)         128       ['conv2d_75[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_72 (LeakyReLU)  (None, 416, 416, 32)         0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  zero_padding2d_5 (ZeroPadd  (None, 417, 417, 32)         0         ['leaky_re_lu_72[0][0]']
#  ing2D)
#
#  conv2d_76 (Conv2D)          (None, 208, 208, 64)         18432     ['zero_padding2d_5[0][0]']
#
#  batch_normalization_73 (Ba  (None, 208, 208, 64)         256       ['conv2d_76[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_73 (LeakyReLU)  (None, 208, 208, 64)         0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  conv2d_77 (Conv2D)          (None, 208, 208, 32)         2048      ['leaky_re_lu_73[0][0]']
#
#  batch_normalization_74 (Ba  (None, 208, 208, 32)         128       ['conv2d_77[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_74 (LeakyReLU)  (None, 208, 208, 32)         0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  conv2d_78 (Conv2D)          (None, 208, 208, 64)         18432     ['leaky_re_lu_74[0][0]']
#
#  batch_normalization_75 (Ba  (None, 208, 208, 64)         256       ['conv2d_78[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_75 (LeakyReLU)  (None, 208, 208, 64)         0         ['batch_normalization_75[0][0]
#                                                                     ']
#
#  tf.__operators__.add_26 (T  (None, 208, 208, 64)         0         ['leaky_re_lu_73[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_75[0][0]']
#
#  zero_padding2d_6 (ZeroPadd  (None, 209, 209, 64)         0         ['tf.__operators__.add_26[0][0
#  ing2D)                                                             ]']
#
#  conv2d_79 (Conv2D)          (None, 104, 104, 128)        73728     ['zero_padding2d_6[0][0]']
#
#  batch_normalization_76 (Ba  (None, 104, 104, 128)        512       ['conv2d_79[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_76 (LeakyReLU)  (None, 104, 104, 128)        0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  conv2d_80 (Conv2D)          (None, 104, 104, 64)         8192      ['leaky_re_lu_76[0][0]']
#
#  batch_normalization_77 (Ba  (None, 104, 104, 64)         256       ['conv2d_80[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_77 (LeakyReLU)  (None, 104, 104, 64)         0         ['batch_normalization_77[0][0]
#                                                                     ']
#
#  conv2d_81 (Conv2D)          (None, 104, 104, 128)        73728     ['leaky_re_lu_77[0][0]']
#
#  batch_normalization_78 (Ba  (None, 104, 104, 128)        512       ['conv2d_81[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_78 (LeakyReLU)  (None, 104, 104, 128)        0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  tf.__operators__.add_27 (T  (None, 104, 104, 128)        0         ['leaky_re_lu_76[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_78[0][0]']
#
#  conv2d_82 (Conv2D)          (None, 104, 104, 64)         8192      ['tf.__operators__.add_27[0][0
#                                                                     ]']
#
#  batch_normalization_79 (Ba  (None, 104, 104, 64)         256       ['conv2d_82[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_79 (LeakyReLU)  (None, 104, 104, 64)         0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  conv2d_83 (Conv2D)          (None, 104, 104, 128)        73728     ['leaky_re_lu_79[0][0]']
#
#  batch_normalization_80 (Ba  (None, 104, 104, 128)        512       ['conv2d_83[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_80 (LeakyReLU)  (None, 104, 104, 128)        0         ['batch_normalization_80[0][0]
#                                                                     ']
#
#  tf.__operators__.add_28 (T  (None, 104, 104, 128)        0         ['tf.__operators__.add_27[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_80[0][0]']
#
#  zero_padding2d_7 (ZeroPadd  (None, 105, 105, 128)        0         ['tf.__operators__.add_28[0][0
#  ing2D)                                                             ]']
#
#  conv2d_84 (Conv2D)          (None, 52, 52, 256)          294912    ['zero_padding2d_7[0][0]']
#
#  batch_normalization_81 (Ba  (None, 52, 52, 256)          1024      ['conv2d_84[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_81 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  conv2d_85 (Conv2D)          (None, 52, 52, 128)          32768     ['leaky_re_lu_81[0][0]']
#
#  batch_normalization_82 (Ba  (None, 52, 52, 128)          512       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_82 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_82[0][0]']
#
#  batch_normalization_83 (Ba  (None, 52, 52, 256)          1024      ['conv2d_86[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_83 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  tf.__operators__.add_29 (T  (None, 52, 52, 256)          0         ['leaky_re_lu_81[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_83[0][0]']
#
#  conv2d_87 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.__operators__.add_29[0][0
#                                                                     ]']
#
#  batch_normalization_84 (Ba  (None, 52, 52, 128)          512       ['conv2d_87[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_84 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  conv2d_88 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_84[0][0]']
#
#  batch_normalization_85 (Ba  (None, 52, 52, 256)          1024      ['conv2d_88[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_85 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  tf.__operators__.add_30 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_29[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_85[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.__operators__.add_30[0][0
#                                                                     ]']
#
#  batch_normalization_86 (Ba  (None, 52, 52, 128)          512       ['conv2d_89[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_86 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  conv2d_90 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_86[0][0]']
#
#  batch_normalization_87 (Ba  (None, 52, 52, 256)          1024      ['conv2d_90[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_87 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  tf.__operators__.add_31 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_30[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_87[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.__operators__.add_31[0][0
#                                                                     ]']
#
#  batch_normalization_88 (Ba  (None, 52, 52, 128)          512       ['conv2d_91[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_88 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  conv2d_92 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_88[0][0]']
#
#  batch_normalization_89 (Ba  (None, 52, 52, 256)          1024      ['conv2d_92[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_89 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  tf.__operators__.add_32 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_31[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_89[0][0]']
#
#  conv2d_93 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.__operators__.add_32[0][0
#                                                                     ]']
#
#  batch_normalization_90 (Ba  (None, 52, 52, 128)          512       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_90 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  conv2d_94 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_90[0][0]']
#
#  batch_normalization_91 (Ba  (None, 52, 52, 256)          1024      ['conv2d_94[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_91 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  tf.__operators__.add_33 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_32[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_91[0][0]']
#
#  conv2d_95 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.__operators__.add_33[0][0
#                                                                     ]']
#
#  batch_normalization_92 (Ba  (None, 52, 52, 128)          512       ['conv2d_95[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_92 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  conv2d_96 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_92[0][0]']
#
#  batch_normalization_93 (Ba  (None, 52, 52, 256)          1024      ['conv2d_96[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_93 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  tf.__operators__.add_34 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_33[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_93[0][0]']
#
#  conv2d_97 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.__operators__.add_34[0][0
#                                                                     ]']
#
#  batch_normalization_94 (Ba  (None, 52, 52, 128)          512       ['conv2d_97[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_94 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_98 (Conv2D)          (None, 52, 52, 256)          294912    ['leaky_re_lu_94[0][0]']
#
#  batch_normalization_95 (Ba  (None, 52, 52, 256)          1024      ['conv2d_98[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_95 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  tf.__operators__.add_35 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_34[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_95[0][0]']
#
#  conv2d_99 (Conv2D)          (None, 52, 52, 128)          32768     ['tf.__operators__.add_35[0][0
#                                                                     ]']
#
#  batch_normalization_96 (Ba  (None, 52, 52, 128)          512       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_96 (LeakyReLU)  (None, 52, 52, 128)          0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  conv2d_100 (Conv2D)         (None, 52, 52, 256)          294912    ['leaky_re_lu_96[0][0]']
#
#  batch_normalization_97 (Ba  (None, 52, 52, 256)          1024      ['conv2d_100[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_97 (LeakyReLU)  (None, 52, 52, 256)          0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  tf.__operators__.add_36 (T  (None, 52, 52, 256)          0         ['tf.__operators__.add_35[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_97[0][0]']
#
#  zero_padding2d_8 (ZeroPadd  (None, 53, 53, 256)          0         ['tf.__operators__.add_36[0][0
#  ing2D)                                                             ]']
#
#  conv2d_101 (Conv2D)         (None, 26, 26, 512)          1179648   ['zero_padding2d_8[0][0]']
#
#  batch_normalization_98 (Ba  (None, 26, 26, 512)          2048      ['conv2d_101[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_98 (LeakyReLU)  (None, 26, 26, 512)          0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  conv2d_102 (Conv2D)         (None, 26, 26, 256)          131072    ['leaky_re_lu_98[0][0]']
#
#  batch_normalization_99 (Ba  (None, 26, 26, 256)          1024      ['conv2d_102[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_99 (LeakyReLU)  (None, 26, 26, 256)          0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  conv2d_103 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_99[0][0]']
#
#  batch_normalization_100 (B  (None, 26, 26, 512)          2048      ['conv2d_103[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_100 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_100[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_37 (T  (None, 26, 26, 512)          0         ['leaky_re_lu_98[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_100[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_37[0][0
#                                                                     ]']
#
#  batch_normalization_101 (B  (None, 26, 26, 256)          1024      ['conv2d_104[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_101 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_101[0][0
#  )                                                                  ]']
#
#  conv2d_105 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_101[0][0]']
#
#  batch_normalization_102 (B  (None, 26, 26, 512)          2048      ['conv2d_105[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_102 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_102[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_38 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_37[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_102[0][0]']
#
#  conv2d_106 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_38[0][0
#                                                                     ]']
#
#  batch_normalization_103 (B  (None, 26, 26, 256)          1024      ['conv2d_106[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_103 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_103[0][0
#  )                                                                  ]']
#
#  conv2d_107 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_103[0][0]']
#
#  batch_normalization_104 (B  (None, 26, 26, 512)          2048      ['conv2d_107[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_104 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_39 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_38[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_104[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_39[0][0
#                                                                     ]']
#
#  batch_normalization_105 (B  (None, 26, 26, 256)          1024      ['conv2d_108[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_105 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_105[0][0
#  )                                                                  ]']
#
#  conv2d_109 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_105[0][0]']
#
#  batch_normalization_106 (B  (None, 26, 26, 512)          2048      ['conv2d_109[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_106 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_40 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_39[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_106[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_40[0][0
#                                                                     ]']
#
#  batch_normalization_107 (B  (None, 26, 26, 256)          1024      ['conv2d_110[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_107 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_107[0][0
#  )                                                                  ]']
#
#  conv2d_111 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_107[0][0]']
#
#  batch_normalization_108 (B  (None, 26, 26, 512)          2048      ['conv2d_111[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_108 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_108[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_41 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_40[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_108[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_41[0][0
#                                                                     ]']
#
#  batch_normalization_109 (B  (None, 26, 26, 256)          1024      ['conv2d_112[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_109 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_109[0][0
#  )                                                                  ]']
#
#  conv2d_113 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_109[0][0]']
#
#  batch_normalization_110 (B  (None, 26, 26, 512)          2048      ['conv2d_113[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_110 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_110[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_42 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_41[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_110[0][0]']
#
#  conv2d_114 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_42[0][0
#                                                                     ]']
#
#  batch_normalization_111 (B  (None, 26, 26, 256)          1024      ['conv2d_114[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_111 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_111[0][0
#  )                                                                  ]']
#
#  conv2d_115 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_111[0][0]']
#
#  batch_normalization_112 (B  (None, 26, 26, 512)          2048      ['conv2d_115[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_112 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_112[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_43 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_42[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_112[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 26, 26, 256)          131072    ['tf.__operators__.add_43[0][0
#                                                                     ]']
#
#  batch_normalization_113 (B  (None, 26, 26, 256)          1024      ['conv2d_116[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_113 (LeakyReLU  (None, 26, 26, 256)          0         ['batch_normalization_113[0][0
#  )                                                                  ]']
#
#  conv2d_117 (Conv2D)         (None, 26, 26, 512)          1179648   ['leaky_re_lu_113[0][0]']
#
#  batch_normalization_114 (B  (None, 26, 26, 512)          2048      ['conv2d_117[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_114 (LeakyReLU  (None, 26, 26, 512)          0         ['batch_normalization_114[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_44 (T  (None, 26, 26, 512)          0         ['tf.__operators__.add_43[0][0
#  FOpLambda)                                                         ]',
#                                                                      'leaky_re_lu_114[0][0]']
#
#  zero_padding2d_9 (ZeroPadd  (None, 27, 27, 512)          0         ['tf.__operators__.add_44[0][0
#  ing2D)                                                             ]']
#
#  conv2d_118 (Conv2D)         (None, 13, 13, 1024)         4718592   ['zero_padding2d_9[0][0]']
#
#  batch_normalization_115 (B  (None, 13, 13, 1024)         4096      ['conv2d_118[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_115 (LeakyReLU  (None, 13, 13, 1024)         0         ['batch_normalization_115[0][0
#  )                                                                  ]']
#
#  conv2d_119 (Conv2D)         (None, 13, 13, 512)          524288    ['leaky_re_lu_115[0][0]']
#
#  batch_normalization_116 (B  (None, 13, 13, 512)          2048      ['conv2d_119[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_116 (LeakyReLU  (None, 13, 13, 512)          0         ['batch_normalization_116[0][0
#  )                                                                  ]']
#
#  conv2d_120 (Conv2D)         (None, 13, 13, 1024)         4718592   ['leaky_re_lu_116[0][0]']
#
#  batch_normalization_117 (B  (None, 13, 13, 1024)         4096      ['conv2d_120[0][0]']
#  atchNormalization)
#
#  leaky_re_lu_117 (LeakyReLU  (None, 13, 13, 1024)         0         ['batch_normalization_117[0][0
#  )                                                                  ]']
#
#  tf.__operators__.add_45 (T  (None, 13, 13, 1024)         0         ['leaky_re_lu_115[0][0]',
#  FOpLambda)                                                          'leaky_re_lu_117[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 13, 13, 512)          524288    ['tf.__operators__.add_45[0][0
#                                                                     ]']
#
#  batch_normalization_118 (B  (None, 13, 13, 512)          2048      ['conv2d_121[0][0]']
#  atchNormalization)
#
# ...
#                                                                      'tf.__operators__.getitem_46[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_46[
#                                                                     0][0]']
#
#  tf.__operators__.getitem_5  (1, 13, 13, 1, 2)            0         ['tf.concat_19[0][0]']
#  3 (SlicingOpLambda)
#
#  tf.__operators__.getitem_2  (None, 52, 52, 3, 2)         0         ['tf.reshape_3[0][0]']
#  9 (SlicingOpLambda)
#
#  tf.tile_11 (TFOpLambda)     (None, 52, 52, 3, 2)         0         ['tf.__operators__.getitem_35[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_27[
#                                                                     0][0]']
#
#  tf.__operators__.getitem_3  (None, 52, 52, 3, 2)         0         ['tf.reshape_3[0][0]']
#  0 (SlicingOpLambda)
#
#  tf.__operators__.getitem_3  (None, 26, 26, 3, 2)         0         ['tf.reshape_4[0][0]']
#  8 (SlicingOpLambda)
#
#  tf.tile_14 (TFOpLambda)     (None, 26, 26, 3, 2)         0         ['tf.__operators__.getitem_44[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_36[
#                                                                     0][0]']
#
#  tf.__operators__.getitem_3  (None, 26, 26, 3, 2)         0         ['tf.reshape_4[0][0]']
#  9 (SlicingOpLambda)
#
#  tf.__operators__.getitem_4  (None, 13, 13, 3, 2)         0         ['tf.reshape_5[0][0]']
#  7 (SlicingOpLambda)
#
#  tf.tile_17 (TFOpLambda)     (None, 13, 13, 3, 2)         0         ['tf.__operators__.getitem_53[
#                                                                     0][0]',
#                                                                      'tf.__operators__.getitem_45[
#                                                                     0][0]']
#
#  tf.__operators__.getitem_4  (None, 13, 13, 3, 2)         0         ['tf.reshape_5[0][0]']
#  8 (SlicingOpLambda)
#
#  tf.math.sigmoid_9 (TFOpLam  (None, 52, 52, 3, 2)         0         ['tf.__operators__.getitem_29[
#  bda)                                                               0][0]']
#
#  tf.cast_3 (TFOpLambda)      (None, 52, 52, 3, 2)         0         ['tf.tile_11[0][0]']
#
#  tf.math.exp_3 (TFOpLambda)  (None, 52, 52, 3, 2)         0         ['tf.__operators__.getitem_30[
#                                                                     0][0]']
#
#  tf.math.sigmoid_12 (TFOpLa  (None, 26, 26, 3, 2)         0         ['tf.__operators__.getitem_38[
#  mbda)                                                              0][0]']
#
#  tf.cast_4 (TFOpLambda)      (None, 26, 26, 3, 2)         0         ['tf.tile_14[0][0]']
#
#  tf.math.exp_4 (TFOpLambda)  (None, 26, 26, 3, 2)         0         ['tf.__operators__.getitem_39[
#                                                                     0][0]']
#
#  tf.math.sigmoid_15 (TFOpLa  (None, 13, 13, 3, 2)         0         ['tf.__operators__.getitem_47[
#  mbda)                                                              0][0]']
#
#  tf.cast_5 (TFOpLambda)      (None, 13, 13, 3, 2)         0         ['tf.tile_17[0][0]']
#
#  tf.math.exp_5 (TFOpLambda)  (None, 13, 13, 3, 2)         0         ['tf.__operators__.getitem_48[
#                                                                     0][0]']
#
#  tf.__operators__.add_49 (T  (None, 52, 52, 3, 2)         0         ['tf.math.sigmoid_9[0][0]',
#  FOpLambda)                                                          'tf.cast_3[0][0]']
#
#  tf.math.multiply_10 (TFOpL  (None, 52, 52, 3, 2)         0         ['tf.math.exp_3[0][0]']
#  ambda)
#
#  tf.__operators__.add_50 (T  (None, 26, 26, 3, 2)         0         ['tf.math.sigmoid_12[0][0]',
#  FOpLambda)                                                          'tf.cast_4[0][0]']
#
#  tf.math.multiply_13 (TFOpL  (None, 26, 26, 3, 2)         0         ['tf.math.exp_4[0][0]']
#  ambda)
#
#  tf.__operators__.add_51 (T  (None, 13, 13, 3, 2)         0         ['tf.math.sigmoid_15[0][0]',
#  FOpLambda)                                                          'tf.cast_5[0][0]']
#
#  tf.math.multiply_16 (TFOpL  (None, 13, 13, 3, 2)         0         ['tf.math.exp_5[0][0]']
#  ambda)
#
#  tf.math.multiply_9 (TFOpLa  (None, 52, 52, 3, 2)         0         ['tf.__operators__.add_49[0][0
#  mbda)                                                              ]']
#
#  tf.math.multiply_11 (TFOpL  (None, 52, 52, 3, 2)         0         ['tf.math.multiply_10[0][0]']
#  ambda)
#
#  tf.__operators__.getitem_3  (None, 52, 52, 3, 1)         0         ['tf.reshape_3[0][0]']
#  1 (SlicingOpLambda)
#
#  tf.__operators__.getitem_3  (None, 52, 52, 3, 10)        0         ['tf.reshape_3[0][0]']
#  2 (SlicingOpLambda)
#
#  tf.math.multiply_12 (TFOpL  (None, 26, 26, 3, 2)         0         ['tf.__operators__.add_50[0][0
#  ambda)                                                             ]']
#
#  tf.math.multiply_14 (TFOpL  (None, 26, 26, 3, 2)         0         ['tf.math.multiply_13[0][0]']
#  ambda)
#
#  tf.__operators__.getitem_4  (None, 26, 26, 3, 1)         0         ['tf.reshape_4[0][0]']
#  0 (SlicingOpLambda)
#
#  tf.__operators__.getitem_4  (None, 26, 26, 3, 10)        0         ['tf.reshape_4[0][0]']
#  1 (SlicingOpLambda)
#
#  tf.math.multiply_15 (TFOpL  (None, 13, 13, 3, 2)         0         ['tf.__operators__.add_51[0][0
#  ambda)                                                             ]']
#
#  tf.math.multiply_17 (TFOpL  (None, 13, 13, 3, 2)         0         ['tf.math.multiply_16[0][0]']
#  ambda)
#
#  tf.__operators__.getitem_4  (None, 13, 13, 3, 1)         0         ['tf.reshape_5[0][0]']
#  9 (SlicingOpLambda)
#
#  tf.__operators__.getitem_5  (None, 13, 13, 3, 10)        0         ['tf.reshape_5[0][0]']
#  0 (SlicingOpLambda)
#
#  tf.concat_14 (TFOpLambda)   (None, 52, 52, 3, 4)         0         ['tf.math.multiply_9[0][0]',
#                                                                      'tf.math.multiply_11[0][0]']
#
#  tf.math.sigmoid_10 (TFOpLa  (None, 52, 52, 3, 1)         0         ['tf.__operators__.getitem_31[
#  mbda)                                                              0][0]']
#
#  tf.math.sigmoid_11 (TFOpLa  (None, 52, 52, 3, 10)        0         ['tf.__operators__.getitem_32[
#  mbda)                                                              0][0]']
#
#  tf.concat_17 (TFOpLambda)   (None, 26, 26, 3, 4)         0         ['tf.math.multiply_12[0][0]',
#                                                                      'tf.math.multiply_14[0][0]']
#
#  tf.math.sigmoid_13 (TFOpLa  (None, 26, 26, 3, 1)         0         ['tf.__operators__.getitem_40[
#  mbda)                                                              0][0]']
#
#  tf.math.sigmoid_14 (TFOpLa  (None, 26, 26, 3, 10)        0         ['tf.__operators__.getitem_41[
#  mbda)                                                              0][0]']
#
#  tf.concat_20 (TFOpLambda)   (None, 13, 13, 3, 4)         0         ['tf.math.multiply_15[0][0]',
#                                                                      'tf.math.multiply_17[0][0]']
#
#  tf.math.sigmoid_16 (TFOpLa  (None, 13, 13, 3, 1)         0         ['tf.__operators__.getitem_49[
#  mbda)                                                              0][0]']
#
#  tf.math.sigmoid_17 (TFOpLa  (None, 13, 13, 3, 10)        0         ['tf.__operators__.getitem_50[
#  mbda)                                                              0][0]']
#
#  tf.concat_15 (TFOpLambda)   (None, 52, 52, 3, 15)        0         ['tf.concat_14[0][0]',
#                                                                      'tf.math.sigmoid_10[0][0]',
#                                                                      'tf.math.sigmoid_11[0][0]']
#
#  tf.concat_18 (TFOpLambda)   (None, 26, 26, 3, 15)        0         ['tf.concat_17[0][0]',
#                                                                      'tf.math.sigmoid_13[0][0]',
#                                                                      'tf.math.sigmoid_14[0][0]']
#
#  tf.concat_21 (TFOpLambda)   (None, 13, 13, 3, 15)        0         ['tf.concat_20[0][0]',
#                                                                      'tf.math.sigmoid_16[0][0]',
#                                                                      'tf.math.sigmoid_17[0][0]']
#
# ==================================================================================================
# Total params: 61624807 (235.08 MB)
# Trainable params: 61572199 (234.88 MB)
# Non-trainable params: 52608 (205.50 KB)
# __________________________________________________________________________________________________
